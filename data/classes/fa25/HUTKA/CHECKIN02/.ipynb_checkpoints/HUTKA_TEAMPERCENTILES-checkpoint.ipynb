# %%
import pandas as pd
import numpy as np
from scipy import stats

import warnings
warnings.filterwarnings("ignore")

# %%
#raw = importData('E29_CHECKIN1_MACROANALYSIS_V1.csv').replace("No Response", np.nan)

# %%
def importData(csv):
    data = pd.read_csv(csv)
    return data

#Break down goal setting and team process into: goals, support, communication, work allocation, team role, and enjoyment
#Then, find the magnitude of such difficulties for each team
def getCategoryDifferences(df, teamNumberCol):
    #Subset df to just goal setting and team process quantitative questions
    columnsOfInterest = [teamNumberCol, "SharedGoalTeamAvg", "SharedGoalClassAvg", 
                         "IndvGoalTeamAvg", "IndvGoalClassAvg", "SupportTeamAvg", 
                         "SupportClassAvg", "CommunicateTeamAvg", "CommunicateClassAvg", 
                         "WorkAllocTeamAvg", "WorkAllocClassAvg", "RoleTeamAvg", 
                         "RoleClassAvg", "EnjoyTeamAvg", "EnjoyClassAvg", 
                        'ConflictResTeamAvg', 'ConflictResClassAvg', 'ConflictResClassStDev',
                        'EfficiencyTeamAvg', 'EfficiencyClassAvg', 'EfficiencyClassStDev',
                        'ExpressionTeamAvg', 'ExpressionClassAvg', 'ExpressionClassStDev']
    temp = df[columnsOfInterest]
    
    #Collapse rows so that 1 row = 1 team
    temp = temp.drop_duplicates()
    
    #Calculate all averages (= team's cumulative deviation from class average)
    temp['goalsDiff'] = (temp["SharedGoalTeamAvg"] + temp["IndvGoalTeamAvg"]) - (temp["SharedGoalClassAvg"] + temp["IndvGoalClassAvg"])
    temp['supportDiff'] = temp["SupportTeamAvg"] - temp["SupportClassAvg"]
    temp['communicateDiff'] = temp["CommunicateTeamAvg"] - temp["CommunicateClassAvg"]
    temp['workAllocationDiff'] = temp["WorkAllocTeamAvg"] - temp["WorkAllocClassAvg"]
    temp['teamRoleDiff'] = temp["RoleTeamAvg"] - temp["RoleClassAvg"]
    temp['enjoyDiff'] = temp["EnjoyTeamAvg"] - temp["EnjoyClassAvg"]
    temp['conflictResDiff'] = temp["ConflictResTeamAvg"] - temp["ConflictResClassAvg"]
    temp['efficiencyDiff'] = temp['EfficiencyTeamAvg'] - temp['EfficiencyClassAvg']
    temp['expressionDiff'] = temp['ExpressionTeamAvg'] - temp['ExpressionClassAvg']
    temp['overallDiff'] = round(temp['goalsDiff'] + temp['supportDiff'] + temp['communicateDiff'] + temp['workAllocationDiff'] + temp['teamRoleDiff'] + temp['enjoyDiff'] + temp['conflictResDiff'] + temp['expressionDiff'] + temp['efficiencyDiff'], 2)
    
    tempRanked = temp.sort_values(teamNumberCol, ascending=True).reset_index(drop=True)
    tempRanked = tempRanked[[teamNumberCol, 'overallDiff', 'goalsDiff', 'supportDiff', 
                             'communicateDiff', 'workAllocationDiff', 'teamRoleDiff', 'enjoyDiff',
                            'conflictResDiff', 'efficiencyDiff', 'expressionDiff']]
    
    return tempRanked

#Assign each team a percentile (score) based on their overall difference from the class average. A difference of 0 designates a 50 (median)
def getTeamPercentiles(df, teamNumberCol):

    arr = np.array(df['overallDiff'])
    df["percentile"] = [round(stats.percentileofscore(arr, x), 2) for x in arr]

    return df
#Assign a category according to each team's percentile
def categorizePercentiles(df, teamNumberCol):
    arr = np.array(df['percentile'])
    cats = []
    #print(arr)
    for score in arr:
        if score >= 75:
            cats.append("Exceptional")
        elif score >= 50 and score < 75:
            cats.append("Strong")
        elif score >= 20 and score < 50:
            cats.append("Standard")
        elif score >= 10 and score < 20:
            cats.append("Weak")
        elif score >= 0 and score < 10:
            cats.append("Needs Attention")
        else:
            cats.append("Team did not respond")
    #print(cats)
    df["percentileCategory"] = cats
    return df

# %%
CHECKIN = pd.read_csv("HUTKA_CHECKIN02_MACROANALYSIS_V1.csv")

# %%
diffs = getCategoryDifferences(CHECKIN, 'TeamNumber')

# %%
percentiles = getTeamPercentiles(diffs, 'TeamNumber')

# %%
scored = categorizePercentiles(percentiles, 'TeamNumber')

# %%
scored.head()
# Out:
#    TeamNumber  overallDiff  goalsDiff  supportDiff  communicateDiff  \
# 0           1         -1.1       -0.8          0.2             -0.3
# 1           2          7.2        1.6          0.8              0.9
# 2           3          3.8        0.6          0.5              0.3
# 3           5          0.9       -0.4         -0.2              0.1
# 4           7          3.2        0.6          0.5              0.1
#
#    workAllocationDiff  teamRoleDiff  enjoyDiff  conflictResDiff  \
# 0                 0.0           0.1       -0.2              0.0
# 1                 1.2           0.4        0.6              0.7
# 2                 0.6           0.1        0.6              0.4
# 3                 0.4           0.1        0.3              0.7
# 4                 0.6           0.4        0.3              0.2
#
#    efficiencyDiff  expressionDiff  percentile percentileCategory
# 0             0.0            -0.1        40.0           Standard
# 1             0.5             0.5       100.0        Exceptional
# 2             0.2             0.5        80.0        Exceptional
# 3             0.0            -0.1        60.0             Strong
# 4             0.0             0.5        70.0             Strong

# %%
roster = pd.read_csv("../HUTKA_ROSTER_V2.csv")
#roster = roster[["TeamName", "TeamNumber"]].drop_duplicates().reset_index()
macro = pd.read_csv("HUTKA_CHECKIN02_MACROANALYSIS_V1.csv")
scored = scored

# %%
scored
# Out:
#    TeamNumber  overallDiff  goalsDiff  supportDiff  communicateDiff  \
# 0           1         -1.1       -0.8          0.2             -0.3
# 1           2          7.2        1.6          0.8              0.9
# 2           3          3.8        0.6          0.5              0.3
# 3           5          0.9       -0.4         -0.2              0.1
# 4           7          3.2        0.6          0.5              0.1
# 5           8         -2.3       -1.4         -0.8              0.1
# 6           9         -1.9        0.2          0.2             -0.1
# 7          10        -23.0       -2.1         -2.3             -3.2
# 8          11          0.8       -0.2          0.0              0.3
# 9          18          4.9        0.6          0.8              0.5
#
#    workAllocationDiff  teamRoleDiff  enjoyDiff  conflictResDiff  \
# 0                 0.0           0.1       -0.2              0.0
# 1                 1.2           0.4        0.6              0.7
# 2                 0.6           0.1        0.6              0.4
# 3                 0.4           0.1        0.3              0.7
# 4                 0.6           0.4        0.3              0.2
# 5                -0.4          -0.1       -0.2              0.4
# 6                -1.6          -1.1        0.4              0.2
# 7                -2.6           0.2       -3.5             -4.5
# 8                 0.2           0.1        0.0              0.2
# 9                 0.8           0.3        0.6              0.6
#
#    efficiencyDiff  expressionDiff  percentile percentileCategory
# 0             0.0            -0.1        40.0           Standard
# 1             0.5             0.5       100.0        Exceptional
# 2             0.2             0.5        80.0        Exceptional
# 3             0.0            -0.1        60.0             Strong
# 4             0.0             0.5        70.0             Strong
# 5             0.2            -0.1        20.0           Standard
# 6            -0.4             0.3        30.0           Standard
# 7            -1.7            -3.3        10.0               Weak
# 8             0.0             0.2        50.0             Strong
# 9             0.4             0.3        90.0        Exceptional

# %%
#scored.to_csv("HUTKA_CHECKIN02_TEAM_PERCENTILES.csv")

# %%
macro.head()
# Out:
#    Unnamed: 0           FullName                        Email  TeamNumber  \
# 0           0   Mackenzie Cramer  mackenzie.hanh@berkeley.edu           1
# 1           1          Evan Haas        evanhaas@berkeley.edu           1
# 2           2          Dinah Lee  jiwondinah.lee@berkeley.edu           1
# 3           3  Catherine McQueen         mcqueen@berkeley.edu           1
# 4           4         Mindy Tsai       mindytsai@berkeley.edu           1
#
#    TeammateNumber  \
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
#
#    Our team is clear about the shared goals for our work together  \
# 0                                                5.0
# 1                                                7.0
# 2                                                5.0
# 3                                                6.0
# 4                                                6.0
#
#    SharedGoalTeamAvg  SharedGoalClassAvg  SharedGoalClassStDev  \
# 0                5.8                 6.3                   0.7
# 1                5.8                 6.3                   0.7
# 2                5.8                 6.3                   0.7
# 3                5.8                 6.3                   0.7
# 4                5.8                 6.3                   0.7
#
#    We each know about one another's individual goals for our work together  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                5.0
# 4                                                6.0
#
#    ...  Communicate2ClassAvg  Communicate2ClassStDev  ExpertiseMe  \
# 0  ...                   6.4                     0.9          5.0
# 1  ...                   6.4                     0.9          7.0
# 2  ...                   6.4                     0.9          6.0
# 3  ...                   6.4                     0.9          7.0
# 4  ...                   6.4                     0.9          6.0
#
#    ExpertiseTeammateAvg  ExpertiseClassAvg  ExpertiseClassStDev  RespectMe  \
# 0                   6.5                6.5                  0.8        5.0
# 1                   6.2                6.5                  0.8        7.0
# 2                   6.5                6.5                  0.8        6.0
# 3                   6.2                6.5                  0.8        7.0
# 4                   3.8                6.5                  0.8        6.0
#
#   RespectTeammateAvg RespectClassAvg RespectClassStDev
# 0                6.5             6.6               0.8
# 1                6.2             6.6               0.8
# 2                6.2             6.6               0.8
# 3                6.0             6.6               0.8
# 4                4.8             6.6               0.8
#
# [5 rows x 114 columns]

# %%
#create column for percentile
macro["percentile"] = [
    scored.loc[scored["TeamNumber"] == number, "percentile"].iloc[0]
    for number in macro["TeamNumber"]
]

# %%
macro["percentileCategory"] = [
    scored.loc[scored["TeamNumber"] == number, "percentileCategory"].iloc[0]
    for number in macro["TeamNumber"]
]

# %%
macro
# Out:
#     Unnamed: 0                    FullName                            Email  \
# 0            0            Mackenzie Cramer      mackenzie.hanh@berkeley.edu
# 1            1                   Evan Haas            evanhaas@berkeley.edu
# 2            2                   Dinah Lee      jiwondinah.lee@berkeley.edu
# 3            3           Catherine McQueen             mcqueen@berkeley.edu
# 4            4                  Mindy Tsai           mindytsai@berkeley.edu
# 5            5              Diara Bagayeva       diarabagayeva@berkeley.edu
# 6            6                  Adeline Li         adeline_zwl@berkeley.edu
# 7            7      Sanjida Quarratul Ain      qurratulain.508@berkeley.edu
# 8            8                   Ivy Zhang            ivyzhang@berkeley.edu
# 9            9                  Anam Ahmed       anamahmed1229@berkeley.edu
# 10          10                   Amy Bezek              abezek@berkeley.edu
# 11          11                   Abbey Mui           abbey.mui@berkeley.edu
# 12          12                 Lauren Tang             ltang16@berkeley.edu
# 13          13                   Sunny Hsu           sunny_hsu@berkeley.edu
# 14          14  Jan Henrik Magnus Jacobsen      henrikjacobsen@berkeley.edu
# 15          15                 Tala Salman         tala.salman@berkeley.edu
# 16          16                    Weiru Ye            weiru_ye@berkeley.edu
# 17          17               Rachita Bisht        rachitabisht@berkeley.edu
# 18          18            Catherine Davodi             cdavodi@berkeley.edu
# 19          19  Gianella Guerrero Cardenas  giannella_guerrero@berkeley.edu
# 20          20          Rheanna Mahboobani          rheanna.gm@berkeley.edu
# 21          21                Chelsea Chen        chelsea_chen@berkeley.edu
# 22          22               Jesselin Elza       jesselin.elza@berkeley.edu
# 23          23                 Longyu Gong         longyu.gong@berkeley.edu
# 24          24                  Deborah Qu           deborahqu@berkeley.edu
# 25          25         Riska Ardilla Putri          riskardlla@berkeley.edu
# 26          26                 Ottie Breen               ottie@berkeley.edu
# 27          27                 Gujri Singh         gujri.singh@berkeley.edu
# 28          28               Octavia Smith     octavia.smith08@berkeley.edu
# 29          29           Jaime Wong Pagano         jaime_wongp@berkeley.edu
# 30          30            Devynn Li Belter           dlibelter@berkeley.edu
# 31          31                 Ruiyang Lin           royan_lam@berkeley.edu
# 32          32              Ernest Makaika            emakaika@berkeley.edu
# 33          33                 Yingjian Wu            kimkimwu@berkeley.edu
# 34          34           Anika Bhagavatula    anikabhagavatula@berkeley.edu
# 35          35                 Steven Feng         steven.feng@berkeley.edu
# 36          36                Quinton King         quintonking@berkeley.edu
# 37          37                  James Ning           jamesning@berkeley.edu
# 38          38                  Dan Hickey          dan_hickey@berkeley.edu
# 39          39                 Victoria Li              vi2jia@berkeley.edu
# 40          40                Mikah Nelson               mikah@berkeley.edu
# 41          41             Pamela Quartson     pamela.quartson@berkeley.edu
# 42          42                 Scarlett Xu               yiyao@berkeley.edu
#
#     TeamNumber  TeammateNumber  \
# 0            1               1
# 1            1               2
# 2            1               3
# 3            1               4
# 4            1               5
# 5            2               1
# 6            2               2
# 7            2               3
# 8            2               4
# 9            3               1
# 10           3               2
# 11           3               3
# 12           3               4
# 13           5               1
# 14           5               2
# 15           5               3
# 16           5               4
# 17           7               1
# 18           7               2
# 19           7               3
# 20           7               4
# 21           8               1
# 22           8               2
# 23           8               3
# 24           8               4
# 25           9               1
# 26           9               2
# 27           9               3
# 28           9               4
# 29           9               5
# 30          10               1
# 31          10               2
# 32          10               3
# 33          10               4
# 34          11               1
# 35          11               2
# 36          11               3
# 37          11               4
# 38          18               1
# 39          18               2
# 40          18               3
# 41          18               4
# 42          18               5
#
#     Our team is clear about the shared goals for our work together  \
# 0                                                 5.0
# 1                                                 7.0
# 2                                                 5.0
# 3                                                 6.0
# 4                                                 6.0
# 5                                                 7.0
# 6                                                 7.0
# 7                                                 7.0
# 8                                                 7.0
# 9                                                 7.0
# 10                                                7.0
# 11                                                6.0
# 12                                                7.0
# 13                                                6.0
# 14                                                6.0
# 15                                                6.0
# 16                                                6.0
# 17                                                6.0
# 18                                                7.0
# 19                                                6.0
# 20                                                7.0
# 21                                                6.0
# 22                                                5.0
# 23                                                6.0
# 24                                                6.0
# 25                                                7.0
# 26                                                7.0
# 27                                                6.0
# 28                                                6.0
# 29                                                7.0
# 30                                                4.0
# 31                                                5.0
# 32                                                6.0
# 33                                                NaN
# 34                                                6.0
# 35                                                6.0
# 36                                                6.0
# 37                                                7.0
# 38                                                7.0
# 39                                                7.0
# 40                                                7.0
# 41                                                6.0
# 42                                                6.0
#
#     SharedGoalTeamAvg  SharedGoalClassAvg  SharedGoalClassStDev  \
# 0                 5.8                 6.3                   0.7
# 1                 5.8                 6.3                   0.7
# 2                 5.8                 6.3                   0.7
# 3                 5.8                 6.3                   0.7
# 4                 5.8                 6.3                   0.7
# 5                 7.0                 6.3                   0.7
# 6                 7.0                 6.3                   0.7
# 7                 7.0                 6.3                   0.7
# 8                 7.0                 6.3                   0.7
# 9                 6.8                 6.3                   0.7
# 10                6.8                 6.3                   0.7
# 11                6.8                 6.3                   0.7
# 12                6.8                 6.3                   0.7
# 13                6.0                 6.3                   0.7
# 14                6.0                 6.3                   0.7
# 15                6.0                 6.3                   0.7
# 16                6.0                 6.3                   0.7
# 17                6.5                 6.3                   0.7
# 18                6.5                 6.3                   0.7
# 19                6.5                 6.3                   0.7
# 20                6.5                 6.3                   0.7
# 21                5.8                 6.3                   0.7
# 22                5.8                 6.3                   0.7
# 23                5.8                 6.3                   0.7
# 24                5.8                 6.3                   0.7
# 25                6.6                 6.3                   0.7
# 26                6.6                 6.3                   0.7
# 27                6.6                 6.3                   0.7
# 28                6.6                 6.3                   0.7
# 29                6.6                 6.3                   0.7
# 30                5.0                 6.3                   0.7
# 31                5.0                 6.3                   0.7
# 32                5.0                 6.3                   0.7
# 33                5.0                 6.3                   0.7
# 34                6.2                 6.3                   0.7
# 35                6.2                 6.3                   0.7
# 36                6.2                 6.3                   0.7
# 37                6.2                 6.3                   0.7
# 38                6.6                 6.3                   0.7
# 39                6.6                 6.3                   0.7
# 40                6.6                 6.3                   0.7
# 41                6.6                 6.3                   0.7
# 42                6.6                 6.3                   0.7
#
#     We each know about one another's individual goals for our work together  \
# 0                                                 6.0
# 1                                                 6.0
# 2                                                 6.0
# 3                                                 5.0
# 4                                                 6.0
# 5                                                 7.0
# 6                                                 7.0
# 7                                                 7.0
# 8                                                 7.0
# 9                                                 7.0
# 10                                                7.0
# 11                                                6.0
# 12                                                5.0
# 13                                                6.0
# 14                                                7.0
# 15                                                5.0
# 16                                                6.0
# 17                                                6.0
# 18                                                7.0
# 19                                                6.0
# 20                                                7.0
# 21                                                6.0
# 22                                                3.0
# 23                                                6.0
# 24                                                6.0
# 25                                                7.0
# 26                                                5.0
# 27                                                5.0
# 28                                                6.0
# 29                                                7.0
# 30                                                5.0
# 31                                                5.0
# 32                                                6.0
# 33                                                NaN
# 34                                                6.0
# 35                                                5.0
# 36                                                7.0
# 37                                                6.0
# 38                                                6.0
# 39                                                7.0
# 40                                                7.0
# 41                                                6.0
# 42                                                6.0
#
#     ...  ExpertiseMe  ExpertiseTeammateAvg  ExpertiseClassAvg  \
# 0   ...          5.0                   6.5                6.5
# 1   ...          7.0                   6.2                6.5
# 2   ...          6.0                   6.5                6.5
# 3   ...          7.0                   6.2                6.5
# 4   ...          6.0                   3.8                6.5
# 5   ...          7.0                   6.7                6.5
# 6   ...          7.0                   7.0                6.5
# 7   ...          7.0                   6.7                6.5
# 8   ...          7.0                   7.0                6.5
# 9   ...          7.0                   7.0                6.5
# 10  ...          7.0                   7.0                6.5
# 11  ...          7.0                   7.0                6.5
# 12  ...          7.0                   7.0                6.5
# 13  ...          6.0                   6.3                6.5
# 14  ...          7.0                   6.3                6.5
# 15  ...  No Response                   6.3                6.5
# 16  ...          7.0                   6.0                6.5
# 17  ...          7.0                   6.7                6.5
# 18  ...          7.0                   6.7                6.5
# 19  ...          6.0                   7.0                6.5
# 20  ...          7.0                   6.7                6.5
# 21  ...          7.0                   6.5                6.5
# 22  ...          6.0                   7.0                6.5
# 23  ...          7.0                   6.5                6.5
# 24  ...  No Response                   6.7                6.5
# 25  ...          7.0                   6.8                6.5
# 26  ...          7.0                   4.5                6.5
# 27  ...          6.0                   7.0                6.5
# 28  ...          6.0                   6.8                6.5
# 29  ...          7.0                   6.8                6.5
# 30  ...          6.0                   7.0                6.5
# 31  ...          7.0                   5.5                6.5
# 32  ...          7.0                   5.0                6.5
# 33  ...  No Response                   6.3                6.5
# 34  ...          7.0                   6.3                6.5
# 35  ...          6.0                   7.0                6.5
# 36  ...          6.0                   6.7                6.5
# 37  ...          7.0                   6.3                6.5
# 38  ...          7.0                   7.0                6.5
# 39  ...          5.0                   7.0                6.5
# 40  ...          7.0                   7.0                6.5
# 41  ...          7.0                   6.8                6.5
# 42  ...          7.0                   6.8                6.5
#
#     ExpertiseClassStDev    RespectMe  RespectTeammateAvg  RespectClassAvg  \
# 0                   0.8          5.0                 6.5              6.6
# 1                   0.8          7.0                 6.2              6.6
# 2                   0.8          6.0                 6.2              6.6
# 3                   0.8          7.0                 6.0              6.6
# 4                   0.8          6.0                 4.8              6.6
# 5                   0.8          7.0                 7.0              6.6
# 6                   0.8          7.0                 7.0              6.6
# 7                   0.8          7.0                 6.7              6.6
# 8                   0.8          7.0                 7.0              6.6
# 9                   0.8          7.0                 7.0              6.6
# 10                  0.8          7.0                 7.0              6.6
# 11                  0.8          7.0                 7.0              6.6
# 12                  0.8          7.0                 7.0              6.6
# 13                  0.8          6.0                 7.0              6.6
# 14                  0.8          7.0                 6.7              6.6
# 15                  0.8  No Response                 6.7              6.6
# 16                  0.8          7.0                 6.7              6.6
# 17                  0.8          7.0                 7.0              6.6
# 18                  0.8          7.0                 7.0              6.6
# 19                  0.8          7.0                 7.0              6.6
# 20                  0.8          7.0                 7.0              6.6
# 21                  0.8          7.0                 6.5              6.6
# 22                  0.8          6.0                 7.0              6.6
# 23                  0.8          7.0                 6.5              6.6
# 24                  0.8  No Response                 6.7              6.6
# 25                  0.8          7.0                 6.8              6.6
# 26                  0.8          7.0                 6.0              6.6
# 27                  0.8          6.0                 7.0              6.6
# 28                  0.8          7.0                 6.8              6.6
# 29                  0.8          7.0                 6.8              6.6
# 30                  0.8          6.0                 6.5              6.6
# 31                  0.8          7.0                 5.5              6.6
# 32                  0.8          6.0                 3.5              6.6
# 33                  0.8  No Response                 5.7              6.6
# 34                  0.8          6.0                 6.3              6.6
# 35                  0.8          6.0                 6.7              6.6
# 36                  0.8          6.0                 6.3              6.6
# 37                  0.8          7.0                 6.0              6.6
# 38                  0.8          7.0                 7.0              6.6
# 39                  0.8          7.0                 7.0              6.6
# 40                  0.8          7.0                 7.0              6.6
# 41                  0.8          7.0                 7.0              6.6
# 42                  0.8          7.0                 7.0              6.6
#
#    RespectClassStDev percentile percentileCategory
# 0                0.8       40.0           Standard
# 1                0.8       40.0           Standard
# 2                0.8       40.0           Standard
# 3                0.8       40.0           Standard
# 4                0.8       40.0           Standard
# 5                0.8      100.0        Exceptional
# 6                0.8      100.0        Exceptional
# 7                0.8      100.0        Exceptional
# 8                0.8      100.0        Exceptional
# 9                0.8       80.0        Exceptional
# 10               0.8       80.0        Exceptional
# 11               0.8       80.0        Exceptional
# 12               0.8       80.0        Exceptional
# 13               0.8       60.0             Strong
# 14               0.8       60.0             Strong
# 15               0.8       60.0             Strong
# 16               0.8       60.0             Strong
# 17               0.8       70.0             Strong
# 18               0.8       70.0             Strong
# 19               0.8       70.0             Strong
# 20               0.8       70.0             Strong
# 21               0.8       20.0           Standard
# 22               0.8       20.0           Standard
# 23               0.8       20.0           Standard
# 24               0.8       20.0           Standard
# 25               0.8       30.0           Standard
# 26               0.8       30.0           Standard
# 27               0.8       30.0           Standard
# 28               0.8       30.0           Standard
# 29               0.8       30.0           Standard
# 30               0.8       10.0               Weak
# 31               0.8       10.0               Weak
# 32               0.8       10.0               Weak
# 33               0.8       10.0               Weak
# 34               0.8       50.0             Strong
# 35               0.8       50.0             Strong
# 36               0.8       50.0             Strong
# 37               0.8       50.0             Strong
# 38               0.8       90.0        Exceptional
# 39               0.8       90.0        Exceptional
# 40               0.8       90.0        Exceptional
# 41               0.8       90.0        Exceptional
# 42               0.8       90.0        Exceptional
#
# [43 rows x 116 columns]

# %%
macro["is_nonrespondent"] = macro["Our team is clear about the shared goals for our work together"].isna()

# %%
macro["SharedGoal"] = macro["Please state in 1-2 sentences what you believe your team's shared goals are for this project."]

# %%
macro["TeamName"] = ["Team " + str(macro["TeamNumber"][i]) for i in range(len(macro))]

# %%
final = macro[[
    "FullName",
    "Email",
    "is_nonrespondent",
    "TeamName",
    "TeamNumber",
    "percentile",
    "percentileCategory",
    "SharedGoalTeamAvg",
    "SharedGoalClassAvg",
    "SharedGoalClassStDev",
    "IndvGoalTeamAvg",
    "IndvGoalClassAvg",
    "IndvGoalClassStDev",
    "SupportTeamAvg",
    "SupportClassAvg",
    "SupportClassStDev",
    "SharedGoal",
    "CommunicateTeamAvg",
    "CommunicateClassAvg",
    "CommunicateClassStDev",
    "WorkAllocTeamAvg",
    "WorkAllocClassAvg",
    "WorkAllocClassStDev",
    "RoleTeamAvg",
    "RoleClassAvg",
    "RoleClassStDev",
    "EnjoyTeamAvg",
    "EnjoyClassAvg",
    "EnjoyClassStDev",
    "ConflictResTeamAvg",
    "ConflictResClassAvg",
    "ConflictResClassStDev",
    "EfficiencyTeamAvg",
    "EfficiencyClassAvg",
    "EfficiencyClassStDev",
    "ExpressionTeamAvg",
    "ExpressionClassAvg",
    "ExpressionClassStDev",
    "MyPoints",
    "TeammateAvgPoints",
    "DidWellMe",
    "DoDiffMe",
    "Contribute1",
    "Contribute2",
    "Contribute3",
    "Contribute4",
    "Contribute5",
    "Improve1",
    "Improve2",
    "Improve3",
    "Improve4",
    "Improve5",
    "InitiativeMe",
    "InitiativeTeammateAvg",
    "InitiativeClassAvg",
    "InitiativeClassStDev",
    "CommunicateMe",
    "CommunicateTeammateAvg",
    "Communicate2ClassAvg",
    "Communicate2ClassStDev",
    "ExpertiseMe",
    "ExpertiseTeammateAvg",
    "ExpertiseClassAvg",
    "ExpertiseClassStDev",
    "RespectMe",
    "RespectTeammateAvg",
    "RespectClassAvg",
    "RespectClassStDev"
]]

# %%
final
# Out:
#                       FullName                            Email  \
# 0             Mackenzie Cramer      mackenzie.hanh@berkeley.edu
# 1                    Evan Haas            evanhaas@berkeley.edu
# 2                    Dinah Lee      jiwondinah.lee@berkeley.edu
# 3            Catherine McQueen             mcqueen@berkeley.edu
# 4                   Mindy Tsai           mindytsai@berkeley.edu
# 5               Diara Bagayeva       diarabagayeva@berkeley.edu
# 6                   Adeline Li         adeline_zwl@berkeley.edu
# 7       Sanjida Quarratul Ain      qurratulain.508@berkeley.edu
# 8                    Ivy Zhang            ivyzhang@berkeley.edu
# 9                   Anam Ahmed       anamahmed1229@berkeley.edu
# 10                   Amy Bezek              abezek@berkeley.edu
# 11                   Abbey Mui           abbey.mui@berkeley.edu
# 12                 Lauren Tang             ltang16@berkeley.edu
# 13                   Sunny Hsu           sunny_hsu@berkeley.edu
# 14  Jan Henrik Magnus Jacobsen      henrikjacobsen@berkeley.edu
# 15                 Tala Salman         tala.salman@berkeley.edu
# 16                    Weiru Ye            weiru_ye@berkeley.edu
# 17               Rachita Bisht        rachitabisht@berkeley.edu
# 18            Catherine Davodi             cdavodi@berkeley.edu
# 19  Gianella Guerrero Cardenas  giannella_guerrero@berkeley.edu
# 20          Rheanna Mahboobani          rheanna.gm@berkeley.edu
# 21                Chelsea Chen        chelsea_chen@berkeley.edu
# 22               Jesselin Elza       jesselin.elza@berkeley.edu
# 23                 Longyu Gong         longyu.gong@berkeley.edu
# 24                  Deborah Qu           deborahqu@berkeley.edu
# 25         Riska Ardilla Putri          riskardlla@berkeley.edu
# 26                 Ottie Breen               ottie@berkeley.edu
# 27                 Gujri Singh         gujri.singh@berkeley.edu
# 28               Octavia Smith     octavia.smith08@berkeley.edu
# 29           Jaime Wong Pagano         jaime_wongp@berkeley.edu
# 30            Devynn Li Belter           dlibelter@berkeley.edu
# 31                 Ruiyang Lin           royan_lam@berkeley.edu
# 32              Ernest Makaika            emakaika@berkeley.edu
# 33                 Yingjian Wu            kimkimwu@berkeley.edu
# 34           Anika Bhagavatula    anikabhagavatula@berkeley.edu
# 35                 Steven Feng         steven.feng@berkeley.edu
# 36                Quinton King         quintonking@berkeley.edu
# 37                  James Ning           jamesning@berkeley.edu
# 38                  Dan Hickey          dan_hickey@berkeley.edu
# 39                 Victoria Li              vi2jia@berkeley.edu
# 40                Mikah Nelson               mikah@berkeley.edu
# 41             Pamela Quartson     pamela.quartson@berkeley.edu
# 42                 Scarlett Xu               yiyao@berkeley.edu
#
#     is_nonrespondent TeamName  TeamNumber  percentile percentileCategory  \
# 0              False   Team 1           1        40.0           Standard
# 1              False   Team 1           1        40.0           Standard
# 2              False   Team 1           1        40.0           Standard
# 3              False   Team 1           1        40.0           Standard
# 4              False   Team 1           1        40.0           Standard
# 5              False   Team 2           2       100.0        Exceptional
# 6              False   Team 2           2       100.0        Exceptional
# 7              False   Team 2           2       100.0        Exceptional
# 8              False   Team 2           2       100.0        Exceptional
# 9              False   Team 3           3        80.0        Exceptional
# 10             False   Team 3           3        80.0        Exceptional
# 11             False   Team 3           3        80.0        Exceptional
# 12             False   Team 3           3        80.0        Exceptional
# 13             False   Team 5           5        60.0             Strong
# 14             False   Team 5           5        60.0             Strong
# 15             False   Team 5           5        60.0             Strong
# 16             False   Team 5           5        60.0             Strong
# 17             False   Team 7           7        70.0             Strong
# 18             False   Team 7           7        70.0             Strong
# 19             False   Team 7           7        70.0             Strong
# 20             False   Team 7           7        70.0             Strong
# 21             False   Team 8           8        20.0           Standard
# 22             False   Team 8           8        20.0           Standard
# 23             False   Team 8           8        20.0           Standard
# 24             False   Team 8           8        20.0           Standard
# 25             False   Team 9           9        30.0           Standard
# 26             False   Team 9           9        30.0           Standard
# 27             False   Team 9           9        30.0           Standard
# 28             False   Team 9           9        30.0           Standard
# 29             False   Team 9           9        30.0           Standard
# 30             False  Team 10          10        10.0               Weak
# 31             False  Team 10          10        10.0               Weak
# 32             False  Team 10          10        10.0               Weak
# 33              True  Team 10          10        10.0               Weak
# 34             False  Team 11          11        50.0             Strong
# 35             False  Team 11          11        50.0             Strong
# 36             False  Team 11          11        50.0             Strong
# 37             False  Team 11          11        50.0             Strong
# 38             False  Team 18          18        90.0        Exceptional
# 39             False  Team 18          18        90.0        Exceptional
# 40             False  Team 18          18        90.0        Exceptional
# 41             False  Team 18          18        90.0        Exceptional
# 42             False  Team 18          18        90.0        Exceptional
#
#     SharedGoalTeamAvg  SharedGoalClassAvg  SharedGoalClassStDev  ...  \
# 0                 5.8                 6.3                   0.7  ...
# 1                 5.8                 6.3                   0.7  ...
# 2                 5.8                 6.3                   0.7  ...
# 3                 5.8                 6.3                   0.7  ...
# 4                 5.8                 6.3                   0.7  ...
# 5                 7.0                 6.3                   0.7  ...
# 6                 7.0                 6.3                   0.7  ...
# 7                 7.0                 6.3                   0.7  ...
# 8                 7.0                 6.3                   0.7  ...
# 9                 6.8                 6.3                   0.7  ...
# 10                6.8                 6.3                   0.7  ...
# 11                6.8                 6.3                   0.7  ...
# 12                6.8                 6.3                   0.7  ...
# 13                6.0                 6.3                   0.7  ...
# 14                6.0                 6.3                   0.7  ...
# 15                6.0                 6.3                   0.7  ...
# 16                6.0                 6.3                   0.7  ...
# 17                6.5                 6.3                   0.7  ...
# 18                6.5                 6.3                   0.7  ...
# 19                6.5                 6.3                   0.7  ...
# 20                6.5                 6.3                   0.7  ...
# 21                5.8                 6.3                   0.7  ...
# 22                5.8                 6.3                   0.7  ...
# 23                5.8                 6.3                   0.7  ...
# 24                5.8                 6.3                   0.7  ...
# 25                6.6                 6.3                   0.7  ...
# 26                6.6                 6.3                   0.7  ...
# 27                6.6                 6.3                   0.7  ...
# 28                6.6                 6.3                   0.7  ...
# 29                6.6                 6.3                   0.7  ...
# 30                5.0                 6.3                   0.7  ...
# 31                5.0                 6.3                   0.7  ...
# 32                5.0                 6.3                   0.7  ...
# 33                5.0                 6.3                   0.7  ...
# 34                6.2                 6.3                   0.7  ...
# 35                6.2                 6.3                   0.7  ...
# 36                6.2                 6.3                   0.7  ...
# 37                6.2                 6.3                   0.7  ...
# 38                6.6                 6.3                   0.7  ...
# 39                6.6                 6.3                   0.7  ...
# 40                6.6                 6.3                   0.7  ...
# 41                6.6                 6.3                   0.7  ...
# 42                6.6                 6.3                   0.7  ...
#
#     Communicate2ClassAvg  Communicate2ClassStDev  ExpertiseMe  \
# 0                    6.4                     0.9          5.0
# 1                    6.4                     0.9          7.0
# 2                    6.4                     0.9          6.0
# 3                    6.4                     0.9          7.0
# 4                    6.4                     0.9          6.0
# 5                    6.4                     0.9          7.0
# 6                    6.4                     0.9          7.0
# 7                    6.4                     0.9          7.0
# 8                    6.4                     0.9          7.0
# 9                    6.4                     0.9          7.0
# 10                   6.4                     0.9          7.0
# 11                   6.4                     0.9          7.0
# 12                   6.4                     0.9          7.0
# 13                   6.4                     0.9          6.0
# 14                   6.4                     0.9          7.0
# 15                   6.4                     0.9  No Response
# 16                   6.4                     0.9          7.0
# 17                   6.4                     0.9          7.0
# 18                   6.4                     0.9          7.0
# 19                   6.4                     0.9          6.0
# 20                   6.4                     0.9          7.0
# 21                   6.4                     0.9          7.0
# 22                   6.4                     0.9          6.0
# 23                   6.4                     0.9          7.0
# 24                   6.4                     0.9  No Response
# 25                   6.4                     0.9          7.0
# 26                   6.4                     0.9          7.0
# 27                   6.4                     0.9          6.0
# 28                   6.4                     0.9          6.0
# 29                   6.4                     0.9          7.0
# 30                   6.4                     0.9          6.0
# 31                   6.4                     0.9          7.0
# 32                   6.4                     0.9          7.0
# 33                   6.4                     0.9  No Response
# 34                   6.4                     0.9          7.0
# 35                   6.4                     0.9          6.0
# 36                   6.4                     0.9          6.0
# 37                   6.4                     0.9          7.0
# 38                   6.4                     0.9          7.0
# 39                   6.4                     0.9          5.0
# 40                   6.4                     0.9          7.0
# 41                   6.4                     0.9          7.0
# 42                   6.4                     0.9          7.0
#
#     ExpertiseTeammateAvg  ExpertiseClassAvg  ExpertiseClassStDev    RespectMe  \
# 0                    6.5                6.5                  0.8          5.0
# 1                    6.2                6.5                  0.8          7.0
# 2                    6.5                6.5                  0.8          6.0
# 3                    6.2                6.5                  0.8          7.0
# 4                    3.8                6.5                  0.8          6.0
# 5                    6.7                6.5                  0.8          7.0
# 6                    7.0                6.5                  0.8          7.0
# 7                    6.7                6.5                  0.8          7.0
# 8                    7.0                6.5                  0.8          7.0
# 9                    7.0                6.5                  0.8          7.0
# 10                   7.0                6.5                  0.8          7.0
# 11                   7.0                6.5                  0.8          7.0
# 12                   7.0                6.5                  0.8          7.0
# 13                   6.3                6.5                  0.8          6.0
# 14                   6.3                6.5                  0.8          7.0
# 15                   6.3                6.5                  0.8  No Response
# 16                   6.0                6.5                  0.8          7.0
# 17                   6.7                6.5                  0.8          7.0
# 18                   6.7                6.5                  0.8          7.0
# 19                   7.0                6.5                  0.8          7.0
# 20                   6.7                6.5                  0.8          7.0
# 21                   6.5                6.5                  0.8          7.0
# 22                   7.0                6.5                  0.8          6.0
# 23                   6.5                6.5                  0.8          7.0
# 24                   6.7                6.5                  0.8  No Response
# 25                   6.8                6.5                  0.8          7.0
# 26                   4.5                6.5                  0.8          7.0
# 27                   7.0                6.5                  0.8          6.0
# 28                   6.8                6.5                  0.8          7.0
# 29                   6.8                6.5                  0.8          7.0
# 30                   7.0                6.5                  0.8          6.0
# 31                   5.5                6.5                  0.8          7.0
# 32                   5.0                6.5                  0.8          6.0
# 33                   6.3                6.5                  0.8  No Response
# 34                   6.3                6.5                  0.8          6.0
# 35                   7.0                6.5                  0.8          6.0
# 36                   6.7                6.5                  0.8          6.0
# 37                   6.3                6.5                  0.8          7.0
# 38                   7.0                6.5                  0.8          7.0
# 39                   7.0                6.5                  0.8          7.0
# 40                   7.0                6.5                  0.8          7.0
# 41                   6.8                6.5                  0.8          7.0
# 42                   6.8                6.5                  0.8          7.0
#
#     RespectTeammateAvg  RespectClassAvg  RespectClassStDev
# 0                  6.5              6.6                0.8
# 1                  6.2              6.6                0.8
# 2                  6.2              6.6                0.8
# 3                  6.0              6.6                0.8
# 4                  4.8              6.6                0.8
# 5                  7.0              6.6                0.8
# 6                  7.0              6.6                0.8
# 7                  6.7              6.6                0.8
# 8                  7.0              6.6                0.8
# 9                  7.0              6.6                0.8
# 10                 7.0              6.6                0.8
# 11                 7.0              6.6                0.8
# 12                 7.0              6.6                0.8
# 13                 7.0              6.6                0.8
# 14                 6.7              6.6                0.8
# 15                 6.7              6.6                0.8
# 16                 6.7              6.6                0.8
# 17                 7.0              6.6                0.8
# 18                 7.0              6.6                0.8
# 19                 7.0              6.6                0.8
# 20                 7.0              6.6                0.8
# 21                 6.5              6.6                0.8
# 22                 7.0              6.6                0.8
# 23                 6.5              6.6                0.8
# 24                 6.7              6.6                0.8
# 25                 6.8              6.6                0.8
# 26                 6.0              6.6                0.8
# 27                 7.0              6.6                0.8
# 28                 6.8              6.6                0.8
# 29                 6.8              6.6                0.8
# 30                 6.5              6.6                0.8
# 31                 5.5              6.6                0.8
# 32                 3.5              6.6                0.8
# 33                 5.7              6.6                0.8
# 34                 6.3              6.6                0.8
# 35                 6.7              6.6                0.8
# 36                 6.3              6.6                0.8
# 37                 6.0              6.6                0.8
# 38                 7.0              6.6                0.8
# 39                 7.0              6.6                0.8
# 40                 7.0              6.6                0.8
# 41                 7.0              6.6                0.8
# 42                 7.0              6.6                0.8
#
# [43 rows x 68 columns]

# %%
final.to_csv("HUTKA_CHECKIN02_FULL_ANALYSIS_V1.csv")
