# %%
from typing import (
    Callable, Any, List, Dict, Type, Tuple
)
import pandas as pd
import numpy as np
from automation.report_gen.processing import clean_qualtrics_data

# %%
raw_path = 'E29_CHECKIN03_RAW_TEXT.csv'
roster_path = 'E29_Qualtrics_Roster_EOS.csv'
question_dict_path = 'E29_QUESTION_DICTIONARY.csv'

# %%
full_cleaned = clean_qualtrics_data(raw_path, roster_path, question_dict_path)

# %%
full_cleaned
# Out:
#                                Email TeamNumber  TeammateNumber  \
# 0            allanzhong@berkeley.edu     Team 1               1
# 1             eclopez19@berkeley.edu     Team 1               2
# 2               jerrick@berkeley.edu     Team 1               3
# 3              simrankk@berkeley.edu     Team 1               4
# 4          miroygarrett@berkeley.edu    Team 10               1
# ..                               ...        ...             ...
# 128  siddhant.vasudevan@berkeley.edu     Team 8               4
# 129        allan.sram16@berkeley.edu     Team 9               1
# 130            arnavp45@berkeley.edu     Team 9               2
# 131           owenlachs@berkeley.edu     Team 9               3
# 132          tyler.peng@berkeley.edu     Team 9               4
#
#     RecipientFirstName             RecipientEmail           33         39.1  \
# 0                Allan    allanzhong@berkeley.edu          Yes            4
# 1          No Response                No Response  No Response  No Response
# 2              Jerrick       jerrick@berkeley.edu          Yes          4.5
# 3               Simran      simrankk@berkeley.edu          Yes          3.5
# 4                 Miro  miroygarrett@berkeley.edu          Yes            4
# ..                 ...                        ...          ...          ...
# 128        No Response                No Response  No Response  No Response
# 129        No Response                No Response  No Response  No Response
# 130              Arnav      arnavp45@berkeley.edu          Yes            4
# 131               Owen     owenlachs@berkeley.edu          Yes            4
# 132              Tyler    tyler.peng@berkeley.edu          Yes          1.5
#
#             39.2         39.3  2.1  ...  19.2  19.3 19.4         19.5  \
# 0            3.5          3.5  2.0  ...   2.0   2.0  2.0        Agree
# 1    No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 2            4.5          4.5  3.0  ...   3.0   3.0  3.0  No Response
# 3              4            3  2.0  ...  -1.0   0.0  1.0  No Response
# 4              5            4  2.0  ...   3.0   3.0  3.0  No Response
# ..           ...          ...  ...  ...   ...   ...  ...          ...
# 128  No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 129  No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 130            4            4  2.0  ...   3.0   3.0  3.0  No Response
# 131          4.5            4  2.0  ...   3.0   3.0  2.0  No Response
# 132          1.5          1.5  1.0  ...   3.0   3.0  3.0  No Response
#
#             19.6           55  \
# 0          Agree  No Response
# 1    No Response  No Response
# 2    No Response            5
# 3    No Response  No Response
# 4    No Response            5
# ..           ...          ...
# 128  No Response  No Response
# 129  No Response  No Response
# 130  No Response  No Response
# 131  No Response            5
# 132  No Response  No Response
#
#                                                     51  \
# 0                                          No Response
# 1                                          No Response
# 2                         How to work in a team better
# 3                                     technical skills
# 4    about applications of GD&T and about my teammates
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  about the effort it takes do develop a product...
# 131            my natural role on a team of engineers.
# 132                      How to make product with team
#
#                                                     52  \
# 0                                          No Response
# 1                                          No Response
# 2                         How to do more manufacturing
# 3                                 more ways to improve
# 4    if we will consider continuing to pursue this ...
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  how this process will be different in the indu...
# 131  How I would perform in a different role on the...
# 132                        How we could have improved
#
#                                                     53  \
# 0                                          No Response
# 1                                          No Response
# 2    How to combine technical and interpersonal skills
# 3                                         final result
# 4     how well received our product and prototype were
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  how easy it was to work when everybody was on ...
# 131  the fact that there was no struggle for power ...
# 132                                 A working product
#
#                                                     54
# 0                                          No Response
# 1                                          No Response
# 2           I could do more technical or manufacturing
# 3                                       had more time
# 4    we came up with the idea for the product earlier.
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130        we did not have as many tedious assignments
# 131  I got more time to develop the project to make...
# 132                                 We had more people
#
# [133 rows x 69 columns]

# %%
roster = pd.read_csv("E29_Qualtrics_Roster_EOS.csv", index_col=0)
dictionary = pd.read_csv("E29_QUESTION_DICTIONARY.csv", index_col=0)
dictionary.index = dictionary.index.astype(str)

# %%
roster
# Out:
#                   FullName First name     Last Name  \
# Index
# 0              Allan Zhong      Allan         Zhong
# 1              Edwin Lopez      Edwin         Lopez
# 2             Jerrick Wang    Jerrick          Wang
# 3      Simran Kaur Khahira     Simran  Kaur Khahira
# 4             Miro Garrett       Miro       Garrett
# ...                    ...        ...           ...
# 129     Siddhant Vasudevan   Siddhant     Vasudevan
# 130          Allan Ramirez      Allan       Ramirez
# 131            Arnav Patel      Arnav         Patel
# 132             Owen Lachs       Owen         Lachs
# 133             Tyler Peng      Tyler          Peng
#
#                                  Email  TeamNumber  TeammateNumber  \
# Index
# 0              allanzhong@berkeley.edu         1.0             1.0
# 1               eclopez19@berkeley.edu         1.0             2.0
# 2                 jerrick@berkeley.edu         1.0             3.0
# 3                simrankk@berkeley.edu         1.0             4.0
# 4            miroygarrett@berkeley.edu        10.0             1.0
# ...                                ...         ...             ...
# 129    siddhant.vasudevan@berkeley.edu         8.0             4.0
# 130          allan.sram16@berkeley.edu         9.0             1.0
# 131              arnavp45@berkeley.edu         9.0             2.0
# 132             owenlachs@berkeley.edu         9.0             3.0
# 133            tyler.peng@berkeley.edu         9.0             4.0
#
#            Teammate1       Teammate2       Teammate3            Teammate4  \
# Index
# 0        Allan Zhong     Edwin Lopez    Jerrick Wang  Simran Kaur Khahira
# 1        Allan Zhong     Edwin Lopez    Jerrick Wang  Simran Kaur Khahira
# 2        Allan Zhong     Edwin Lopez    Jerrick Wang  Simran Kaur Khahira
# 3        Allan Zhong     Edwin Lopez    Jerrick Wang  Simran Kaur Khahira
# 4       Miro Garrett  Taiki Yamamoto    Taylor Jazan       Toren Andersen
# ...              ...             ...             ...                  ...
# 129      Adrian Guan     Ayush Patel  Maithili Kumar   Siddhant Vasudevan
# 130    Allan Ramirez     Arnav Patel      Owen Lachs           Tyler Peng
# 131    Allan Ramirez     Arnav Patel      Owen Lachs           Tyler Peng
# 132    Allan Ramirez     Arnav Patel      Owen Lachs           Tyler Peng
# 133    Allan Ramirez     Arnav Patel      Owen Lachs           Tyler Peng
#
#                                      SharedGoal_Checkin1  \
# Index
# 0      Our shared goals are open communication, quali...
# 1      Everyone contributing their fair share of work...
# 2      Collaborate to generate a gearbox design that ...
# 3      Team Goal would be to efficiently work togethe...
# 4      Make something interesting yet still within ca...
# ...                                                  ...
# 129    To create something which addresses an accessi...
# 130                                                  NaN
# 131    We hope to work together smoothly to complete ...
# 132    Our shared goals involved collaborating in a r...
# 133    To improve our ability to design a product for...
#
#                                      SharedGoal_Checkin2  \
# Index
# 0      open communication, equal workload, friendly a...
# 1                                                    NaN
# 2      Redesign a new product with comparable quality...
# 3      Well our project has changed, so the goal now ...
# 4      We hope to provide increased opportunities for...
# ...                                                  ...
# 129    To create something which addresses an accessi...
# 130                                                  NaN
# 131    We hope to create a working prototype of an ad...
# 132    Produce an effective .device to enhance human ...
# 133    To learn about creating an effective and manuf...
#
#                                             TopInterest1  \
# Index
# 0           I encourage others on the team to contribute
# 1                          I do a fair share of the work
# 2         I communicate information and feelings clearly
# 3      I teach my teammates how to do elements of the...
# 4             I ask my teammates for help when I need it
# ...                                                  ...
# 129    I ask my teammates for feedback on how I can i...
# 130    I prepare for, arrive on time for and fully pa...
# 131    I teach my teammates how to do elements of the...
# 132                                I keep my commitments
# 133       I communicate information and feelings clearly
#
#                                             TopInterest2  \
# Index
# 0      I help my team adhere to schedules, e.g., enga...
# 1         I communicate information and feelings clearly
# 2      I help my team adhere to schedules, e.g., enga...
# 3      I encourage my team to set aside time for feed...
# 4      I encourage my team to set high goals and sust...
# ...                                                  ...
# 129    I help my team adhere to schedules, e.g., enga...
# 130    I pay attention to whether our team as a whole...
# 131    I ask my teammates for feedback on how I can i...
# 132    I respond promptly to communication from my te...
# 133           I ask my teammates for help when I need it
#
#                                             TopInterest3
# Index
# 0      I help my teammates recognize the value of the...
# 1      I facilitate exchange of ideas among my teammates
# 2      I help my teammates recognize the value of the...
# 3      I help my teammates recognize the value of the...
# 4      I help my teammates recognize the value of the...
# ...                                                  ...
# 129    I encourage my team to set aside time for feed...
# 130    I encourage my team to set high goals and sust...
# 131    I encourage my team to set aside time for feed...
# 132    I encourage my team to set aside time for feed...
# 133    I help my team adhere to schedules, e.g., enga...
#
# [133 rows x 15 columns]

# %%
quant = dictionary.query('`type` == "quantitative"').index.to_list()
numerical_data = full_cleaned[['TeamNumber', 'TeammateNumber']].join(full_cleaned[quant])
numerical_data.index = full_cleaned.Email
# convert TeamNumber to int
for df in (roster, full_cleaned, numerical_data):
    df['TeamNumber'] = df['TeamNumber'].str.replace('Team ', '', regex=False).astype(float)

roster['TeammateNumber'] = roster['TeammateNumber'].astype(float)

# %%
# Out:
# Index(['1.0', '2.1', '2.2', '2.3', '3.0', '4.1', '4.2', '4.3', '4.4', '5.1',
#        '5.2', '5.3', '5.4', '6.0', '7.0', '14.1', '14.2', '14.3', '14.4',
#        '15.1', '15.2', '15.3', '15.4', '16.1', '16.2', '16.3', '16.4', '17.1',
#        '17.2', '17.3', '17.4', '18.1', '18.2', '18.3', '18.4', '19.1', '19.2',
#        '19.3', '19.4', '33.0', '38.1', '38.2', '38.3', '99.9'],
#       dtype='object', name='question_id')

# %%
def _keep_numeric_cols(df, question):
    relevant_columns = df.loc[:, df.columns.str.startswith(question)]
    # get only numeric columns
    keep_cols = []
    for idx, row in pd.DataFrame(relevant_columns.dtypes).iterrows():
        if row[0] in ['int', 'float']:
            keep_cols.append(idx)
            
    relevant_columns = df[keep_cols]
    
    return relevant_columns

def get_team_average(df, question):
    # Gets average on specified question for each team in df
    return df[['TeamNumber', question]].groupby('TeamNumber').mean()

def get_teammates_average(df, question):
    def apply_helper(row, apply_df):
        team_number, teammate_number = row['TeamNumber'], int(row['TeammateNumber'])
        apply_df = apply_df.loc[
            (apply_df['TeamNumber'] == team_number) & (apply_df['TeammateNumber'] != teammate_number), 
            f'{question}.{teammate_number}'
        ]
        return np.nanmean(apply_df)

    return df.apply(apply_helper, axis=1, apply_df=df)
    
def get_teammates_std(df: pd.DataFrame, question: str):
    def apply_helper(row, apply_df):
        team_number, teammate_number = row['TeamNumber'], int(row['TeammateNumber'])
        apply_df = apply_df.loc[
            (apply_df['TeamNumber'] == team_number) & (apply_df['TeammateNumber'] != teammate_number), 
            f'{question}.{teammate_number}'
        ]
        return np.nanstd(apply_df)

    return df.apply(apply_helper, axis=1, df=df)

def get_response_by_teammate_number(df, teammate_number, question):
    return df.loc[:, f'{question}.{teammate_number}']

def get_my_response(df: pd.DataFrame, question: str) -> pd.Series:
    def apply_helper(row):
        teammate_number = int(row['TeammateNumber'])
        return row[f'{question}.{teammate_number}']
    return df.apply(apply_helper, axis=1)

def get_class_average(df: pd.DataFrame, question: str) -> float:
    # Returns the class average for QUESTION
    return float(np.mean(df[question]))

def get_class_average_all_teammates(df: pd.DataFrame, question: str) -> float:
    return np.nanmean(_keep_numeric_cols(df, question))

def get_class_stdev(df: pd.DataFrame, question: str) -> float:
    # Returns the class std dev for QUESTION
    return float(np.std(df[question]))

def get_class_stdev_all_teammates(df: pd.DataFrame, question: str) -> float:
    return np.nanstd(_keep_numeric_cols(df, question))

# %%
full_cleaned.loc[:, full_cleaned.columns != '16.1']
# Out:
#                                Email  TeamNumber  TeammateNumber  \
# 0            allanzhong@berkeley.edu         1.0               1
# 1             eclopez19@berkeley.edu         1.0               2
# 2               jerrick@berkeley.edu         1.0               3
# 3              simrankk@berkeley.edu         1.0               4
# 4          miroygarrett@berkeley.edu        10.0               1
# ..                               ...         ...             ...
# 128  siddhant.vasudevan@berkeley.edu         8.0               4
# 129        allan.sram16@berkeley.edu         9.0               1
# 130            arnavp45@berkeley.edu         9.0               2
# 131           owenlachs@berkeley.edu         9.0               3
# 132          tyler.peng@berkeley.edu         9.0               4
#
#     RecipientFirstName             RecipientEmail           33         39.1  \
# 0                Allan    allanzhong@berkeley.edu          Yes            4
# 1          No Response                No Response  No Response  No Response
# 2              Jerrick       jerrick@berkeley.edu          Yes          4.5
# 3               Simran      simrankk@berkeley.edu          Yes          3.5
# 4                 Miro  miroygarrett@berkeley.edu          Yes            4
# ..                 ...                        ...          ...          ...
# 128        No Response                No Response  No Response  No Response
# 129        No Response                No Response  No Response  No Response
# 130              Arnav      arnavp45@berkeley.edu          Yes            4
# 131               Owen     owenlachs@berkeley.edu          Yes            4
# 132              Tyler    tyler.peng@berkeley.edu          Yes          1.5
#
#             39.2         39.3  2.1  ...  19.2  19.3 19.4         19.5  \
# 0            3.5          3.5  2.0  ...   2.0   2.0  2.0        Agree
# 1    No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 2            4.5          4.5  3.0  ...   3.0   3.0  3.0  No Response
# 3              4            3  2.0  ...  -1.0   0.0  1.0  No Response
# 4              5            4  2.0  ...   3.0   3.0  3.0  No Response
# ..           ...          ...  ...  ...   ...   ...  ...          ...
# 128  No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 129  No Response  No Response  NaN  ...   NaN   NaN  NaN  No Response
# 130            4            4  2.0  ...   3.0   3.0  3.0  No Response
# 131          4.5            4  2.0  ...   3.0   3.0  2.0  No Response
# 132          1.5          1.5  1.0  ...   3.0   3.0  3.0  No Response
#
#             19.6           55  \
# 0          Agree  No Response
# 1    No Response  No Response
# 2    No Response            5
# 3    No Response  No Response
# 4    No Response            5
# ..           ...          ...
# 128  No Response  No Response
# 129  No Response  No Response
# 130  No Response  No Response
# 131  No Response            5
# 132  No Response  No Response
#
#                                                     51  \
# 0                                          No Response
# 1                                          No Response
# 2                         How to work in a team better
# 3                                     technical skills
# 4    about applications of GD&T and about my teammates
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  about the effort it takes do develop a product...
# 131            my natural role on a team of engineers.
# 132                      How to make product with team
#
#                                                     52  \
# 0                                          No Response
# 1                                          No Response
# 2                         How to do more manufacturing
# 3                                 more ways to improve
# 4    if we will consider continuing to pursue this ...
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  how this process will be different in the indu...
# 131  How I would perform in a different role on the...
# 132                        How we could have improved
#
#                                                     53  \
# 0                                          No Response
# 1                                          No Response
# 2    How to combine technical and interpersonal skills
# 3                                         final result
# 4     how well received our product and prototype were
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130  how easy it was to work when everybody was on ...
# 131  the fact that there was no struggle for power ...
# 132                                 A working product
#
#                                                     54
# 0                                          No Response
# 1                                          No Response
# 2           I could do more technical or manufacturing
# 3                                       had more time
# 4    we came up with the idea for the product earlier.
# ..                                                 ...
# 128                                        No Response
# 129                                        No Response
# 130        we did not have as many tedious assignments
# 131  I got more time to develop the project to make...
# 132                                 We had more people
#
# [133 rows x 68 columns]

# %%
analysis_v2 = roster[["FullName", "Email", "TeamNumber", "TeammateNumber"]].copy()

# %%
class ColumnBuilder:
    def __init__(
        self,
        col_prefix: str,
        col_suffix: str,
        pd_function: Callable[..., pd.DataFrame | pd.Series | int | float],
        pd_function_args: List[Any]
    ):
        self.col_prefix = col_prefix
        self.col_suffix = col_suffix
        self.pd_function = pd_function
        self.pd_function_args = pd_function_args

    def __call__(self, df: pd.DataFrame) -> pd.DataFrame:
        new_col_name = f'{self.col_prefix}{self.col_suffix}'
        pd_result = self.pd_function(df, *self.pd_function_args)
        # if unequal length of series, need to perform merge on index of result
        if type(pd_result) == pd.DataFrame and len(pd_result != len(df)):
            index_name = pd_result.index.name
            pd_result.columns = pd.Index([new_col_name])

            return pd.merge(df, pd_result, how='left', on=index_name)

        # singular value will be broadcasted on whole column
        # or same length of series and dataframe
        else:
            return df.assign(**{
                new_col_name: self.pd_function(df, *self.pd_function_args)
            })

class Identity(ColumnBuilder):
    def __init__(self, col_prefix: str, col_suffix: str, question: str):
        super().__init__(col_prefix, col_suffix, lambda df, q: df[q], [question])

class ClassAvg(ColumnBuilder):
    def __init__(self, col_prefix: str, question: str):
        super().__init__(col_prefix, 'ClassAvg', get_class_average, [question])

class ClassStDev(ColumnBuilder):
    def __init__(self, col_prefix: str, question: str):
        super().__init__(col_prefix, 'ClassStDev', get_class_stdev, [question])

class TeammateAvg(ColumnBuilder):
    def __init__(self, col_prefix: str, question: str):
        super().__init__(col_prefix, 'TeammateAvg', get_teammates_average, [question])

    def __call__(self, df: pd.DataFrame) -> pd.DataFrame:
        result = super().__call__(df)
        return result

class TeamAvg(ColumnBuilder):
    def __init__(self, col_prefix: str, question: str):
        super().__init__(col_prefix, 'TeamAvg', get_team_average, [question])

class AcrossTeammates(ColumnBuilder):
    # only use this for class avg across all teammate responses
    pass

class PerMemberFunc(ColumnBuilder):
    # no need to override __init__

    def __call__(self, df: pd.DataFrame) -> pd.DataFrame:
        team_size = max(df['TeammateNumber'].unique())

        for i in range(1, team_size+1):
            df = ColumnBuilder(
                self.col_prefix,
                str(i),
                get_response_by_teammate_number,
                [i] + self.pd_function_args
            )(df)

        return df

# %%
suffix_to_columnbuilder: Dict[str, Type[ColumnBuilder]] = {
    'TeamAvg': TeamAvg,
    'TeammateAvg': TeammateAvg,
    '': Identity,
    'Me': Identity,
    'ClassAvg': ClassAvg,
    'ClassStDev': ClassStDev,
    'PerMember': PerMemberFunc,
}

col_to_prefix: Dict[str, str] = {
    '2.1': 'SharedGoal',
    '2.2': 'IndvGoal',
    '2.3': 'Support',
    '4.1': 'Communicate',
    '4.2': 'WorkAlloc',
    '4.3': 'Role',
    '4.4': 'Enjoy',
    '5': 'Points',
    '6': 'DidWell',
    '7': 'DoDiff',
    '14': 'Contribute',
    '15': 'Improve',
    '16': 'Initiative',
    '17': 'Communicate',
    '18': 'Expertise',
    '19': 'Respect',
}

# %%
pd.Series(col_to_prefix).to_dict()
# Out:
# {'2.1': 'SharedGoal',
#  '2.2': 'IndvGoal',
#  '2.3': 'Support',
#  '4.1': 'Communicate',
#  '4.2': 'WorkAlloc',
#  '4.3': 'Role',
#  '4.4': 'Enjoy',
#  '5': 'Points',
#  '6': 'DidWell',
#  '7': 'DoDiff',
#  '14': 'Contribute',
#  '15': 'Improve',
#  '16': 'Initiative',
#  '17': 'Communicate',
#  '18': 'Expertise',
#  '19': 'Respect'}

# %%
dictionary
# Out:
#                                                       question  \
# question_id
# 1.0                                introduction and background
# 2.1          Our team is clear about the shared goals for o...
# 2.2          We each know about one another's individual go...
# 2.3          I feel supported by my teammates in the pursui...
# 3.0          Please state in 1-2 sentences what you believe...
# 4.1               We have good communication amongst ourselves
# 4.2                We fairly distribute work amongst ourselves
# 4.3               I am clear about the roles I play on my team
# 4.4                          I enjoy working with my teammates
# 5.1          Please allocate 100 points across yourself and...
# 5.2          Please allocate 100 points across yourself and...
# 5.3          Please allocate 100 points across yourself and...
# 5.4          Please allocate 100 points across yourself and...
# 6.0          Name one concrete and specific thing that your...
# 7.0          Name one concrete and specific thing that you ...
# 14.1         For each of your teammates and yourself, write...
# 14.2         For each of your teammates and yourself, write...
# 14.3         For each of your teammates and yourself, write...
# 14.4         For each of your teammates and yourself, write...
# 15.1         For each of your teammates listed below, write...
# 15.2         For each of your teammates listed below, write...
# 15.3         For each of your teammates listed below, write...
# 15.4         For each of your teammates listed below, write...
# 16.1         Took initiative to help the team problem solve...
# 16.2         Took initiative to help the team problem solve...
# 16.3         Took initiative to help the team problem solve...
# 16.4         Took initiative to help the team problem solve...
# 17.1         Communicated information and feelings openly, ...
# 17.2         Communicated information and feelings openly, ...
# 17.3         Communicated information and feelings openly, ...
# 17.4         Communicated information and feelings openly, ...
# 18.1         Contributed expertise and effort in team activ...
# 18.2         Contributed expertise and effort in team activ...
# 18.3         Contributed expertise and effort in team activ...
# 18.4         Contributed expertise and effort in team activ...
# 19.1         Respected and valued other team members to bri...
# 19.2         Respected and valued other team members to bri...
# 19.3         Respected and valued other team members to bri...
# 19.4         Respected and valued other team members to bri...
# 33.0         My team’s primary mode of communication to com...
# 38.1         How well have you improved in the element: ELE...
# 38.2         How well have you improved in the element: ELE...
# 38.3         How well have you improved in the element: ELE...
# 99.9           Please refer to your personalized feedback here
#
#                                         category          type  \
# question_id
# 1.0                                          NaN           NaN
# 2.1                                 Goal Setting  quantitative
# 2.2                                 Goal Setting  quantitative
# 2.3                                 Goal Setting  quantitative
# 3.0                                 Goal Setting   qualitative
# 4.1                                 Team Process  quantitative
# 4.2                                 Team Process  quantitative
# 4.3                                 Team Process  quantitative
# 4.4                                 Team Process  quantitative
# 5.1                                 Team Process  quantitative
# 5.2                                 Team Process  quantitative
# 5.3                                 Team Process  quantitative
# 5.4                                 Team Process  quantitative
# 6.0                        Individual Reflection   qualitative
# 7.0                        Individual Reflection   qualitative
# 14.1         Teammate Contributions and Feedback   qualitative
# 14.2         Teammate Contributions and Feedback   qualitative
# 14.3         Teammate Contributions and Feedback   qualitative
# 14.4         Teammate Contributions and Feedback   qualitative
# 15.1         Teammate Contributions and Feedback   qualitative
# 15.2         Teammate Contributions and Feedback   qualitative
# 15.3         Teammate Contributions and Feedback   qualitative
# 15.4         Teammate Contributions and Feedback   qualitative
# 16.1         Teammate Contributions and Feedback  quantitative
# 16.2         Teammate Contributions and Feedback  quantitative
# 16.3         Teammate Contributions and Feedback  quantitative
# 16.4         Teammate Contributions and Feedback  quantitative
# 17.1         Teammate Contributions and Feedback  quantitative
# 17.2         Teammate Contributions and Feedback  quantitative
# 17.3         Teammate Contributions and Feedback  quantitative
# 17.4         Teammate Contributions and Feedback  quantitative
# 18.1         Teammate Contributions and Feedback  quantitative
# 18.2         Teammate Contributions and Feedback  quantitative
# 18.3         Teammate Contributions and Feedback  quantitative
# 18.4         Teammate Contributions and Feedback  quantitative
# 19.1         Teammate Contributions and Feedback  quantitative
# 19.2         Teammate Contributions and Feedback  quantitative
# 19.3         Teammate Contributions and Feedback  quantitative
# 19.4         Teammate Contributions and Feedback  quantitative
# 33.0                               Communication   qualitative
# 38.1                       Individual Reflection  quantitative
# 38.2                       Individual Reflection  quantitative
# 38.3                       Individual Reflection  quantitative
# 99.9                       Individual Reflection   qualitative
#
#                               scale  out_of  \
# question_id
# 1.0                             NaN     NaN
# 2.1                         -3 to 3     7.0
# 2.2                         -3 to 3     7.0
# 2.3                         -3 to 3     7.0
# 3.0          No scale (qualitative)     NaN
# 4.1                         -3 to 3     7.0
# 4.2                         -3 to 3     7.0
# 4.3                         -3 to 3     7.0
# 4.4                         -3 to 3     7.0
# 5.1                           1-100   100.0
# 5.2                           1-100   100.0
# 5.3                           1-100   100.0
# 5.4                           1-100   100.0
# 6.0          No scale (qualitative)     NaN
# 7.0          No scale (qualitative)     NaN
# 14.1         No scale (qualitative)     NaN
# 14.2         No scale (qualitative)     NaN
# 14.3         No scale (qualitative)     NaN
# 14.4         No scale (qualitative)     NaN
# 15.1         No scale (qualitative)     NaN
# 15.2         No scale (qualitative)     NaN
# 15.3         No scale (qualitative)     NaN
# 15.4         No scale (qualitative)     NaN
# 16.1                        -3 to 3     7.0
# 16.2                        -3 to 3     7.0
# 16.3                        -3 to 3     7.0
# 16.4                        -3 to 3     7.0
# 17.1                        -3 to 3     7.0
# 17.2                        -3 to 3     7.0
# 17.3                        -3 to 3     7.0
# 17.4                        -3 to 3     7.0
# 18.1                        -3 to 3     7.0
# 18.2                        -3 to 3     7.0
# 18.3                        -3 to 3     7.0
# 18.4                        -3 to 3     7.0
# 19.1                        -3 to 3     7.0
# 19.2                        -3 to 3     7.0
# 19.3                        -3 to 3     7.0
# 19.4                        -3 to 3     7.0
# 33.0                            NaN     4.0
# 38.1                        -3 to 3     7.0
# 38.2                        -3 to 3     7.0
# 38.3                        -3 to 3     7.0
# 99.9         No scale (qualitative)     NaN
#
#                                                          notes
# question_id
# 1.0          FOR COMPLETE SCORING:
# Option 1: 1 = strongly ...
# 2.1                 -3 = strongly disagree, 3 = strongly agree
# 2.2                 -3 = strongly disagree, 3 = strongly agree
# 2.3                 -3 = strongly disagree, 3 = strongly agree
# 3.0                                     No scale (qualitative)
# 4.1                 -3 = strongly disagree, 3 = strongly agree
# 4.2                 -3 = strongly disagree, 3 = strongly agree
# 4.3                 -3 = strongly disagree, 3 = strongly agree
# 4.4                 -3 = strongly disagree, 3 = strongly agree
# 5.1              1 = no contribution, 100 = total contribution
# 5.2              1 = no contribution, 100 = total contribution
# 5.3              1 = no contribution, 100 = total contribution
# 5.4              1 = no contribution, 100 = total contribution
# 6.0                                     No scale (qualitative)
# 7.0                                     No scale (qualitative)
# 14.1                                    No scale (qualitative)
# 14.2                                    No scale (qualitative)
# 14.3                                    No scale (qualitative)
# 14.4                                    No scale (qualitative)
# 15.1                                    No scale (qualitative)
# 15.2                                    No scale (qualitative)
# 15.3                                    No scale (qualitative)
# 15.4                                    No scale (qualitative)
# 16.1                -3 = strongly disagree, 3 = strongly agree
# 16.2                -3 = strongly disagree, 3 = strongly agree
# 16.3                -3 = strongly disagree, 3 = strongly agree
# 16.4                -3 = strongly disagree, 3 = strongly agree
# 17.1                -3 = strongly disagree, 3 = strongly agree
# 17.2                -3 = strongly disagree, 3 = strongly agree
# 17.3                -3 = strongly disagree, 3 = strongly agree
# 17.4                -3 = strongly disagree, 3 = strongly agree
# 18.1                -3 = strongly disagree, 3 = strongly agree
# 18.2                -3 = strongly disagree, 3 = strongly agree
# 18.3                -3 = strongly disagree, 3 = strongly agree
# 18.4                -3 = strongly disagree, 3 = strongly agree
# 19.1                -3 = strongly disagree, 3 = strongly agree
# 19.2                -3 = strongly disagree, 3 = strongly agree
# 19.3                -3 = strongly disagree, 3 = strongly agree
# 19.4                -3 = strongly disagree, 3 = strongly agree
# 33.0                                                       NaN
# 38.1                          -3 = much worse, 3 = much better
# 38.2                          -3 = much worse, 3 = much better
# 38.3                          -3 = much worse, 3 = much better
# 99.9                                    No scale (qualitative)

# %%
def column_builder_pipe(
        df: pd.DataFrame,
        column_builder_params: List[Tuple],
        col_to_prefix: Dict[str, str]
) -> pd.DataFrame:
    for (question, suffix, func, func_args) in column_builder_params:
        prefix = col_to_prefix[question]
        if suffix in suffix_to_columnbuilder:
            builder_type = suffix_to_columnbuilder[suffix]
            
            if builder_type == PerMemberFunc:
                cb = builder_type(prefix, suffix, func, func_args)
            elif func is not None:
                cb = ColumnBuilder(prefix, suffix, func, func_args)
            else:
                if builder_type == Identity:
                    cb = builder_type(prefix, suffix, question)
                elif builder_type == PerMemberFunc:
                    cb = builder_type(prefix, suffix, func, func_args)
                else:
                    cb = builder_type(prefix, question)

        else:
            cb = ColumnBuilder(prefix, suffix, func, func_args)

        df = df.pipe(cb)

    return df

# %%
full_cleaned.columns
# Out:
# Index(['Email', 'TeamNumber', 'TeammateNumber', 'RecipientFirstName',
#        'RecipientEmail', '33', '39.1', '39.2', '39.3', '2.1', '2.2', '2.3',
#        '3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', '5.3', '5.4', '5.5',
#        '5.7', '6', '7', '38.1', '38.2', '38.3', '14.1', '14.2', '14.3', '14.4',
#        '14.5', '14.6', '15.1', '15.2', '15.3', '15.4', '15.5', '15.6', '16.1',
#        '16.2', '16.3', '16.4', '16.5', '16.6', '17.1', '17.2', '17.3', '17.4',
#        '17.5', '17.6', '18.1', '18.2', '18.3', '18.4', '18.5', '18.6', '19.1',
#        '19.2', '19.3', '19.4', '19.5', '19.6', '55', '51', '52', '53', '54'],
#       dtype='object')

# %%
sample_params = [
    ('2.1', 'TeamAvg', None, None),
    ('2.1', 'ClassAvg', None, None),
    ('2.1', 'ClassStDev', None, None),
    ('2.2', 'TeamAvg', None, None),
    ('2.3', 'TeamAvg', None, None),
    ('4.1', 'TeamAvg', None, None),
    ('4.1', 'ClassAvg', None, None),
    ('4.1', 'ClassStDev', None, None),
    ('4.2', 'TeamAvg', None, None),
    ('4.2', 'ClassAvg', None, None),
    ('4.2', 'ClassStDev', None, None),
    ('4.3', 'TeamAvg', None, None),
    ('4.3', 'ClassAvg', None, None),
    ('4.3', 'ClassStDev', None, None),
    ('4.4', 'TeamAvg', None, None),
    ('4.4', 'ClassAvg', None, None),
    ('4.4', 'ClassStDev', None, None),
    ('5', 'Me', get_my_response, ['5']),
    ('5', 'TeammateAvg', None, None),
    ('6', 'Me', None, None),
    ('7', 'Me', None, None),
    ('14', 'Me', get_my_response, ['14']),
    ('14', 'PerMember', None, ['14']),
    ('15', 'Me', get_my_response, ['15']),
    ('15', 'PerMember', None, ['15']),
    ('16', 'Me', get_my_response, ['16']),
    ('16', 'TeammateAvg', None, None),
    ('16', 'ClassAvg', get_class_average_all_teammates, ['16']),
    ('16', 'ClassStDev', get_class_stdev_all_teammates, ['16']),
    ('17', 'Me', get_my_response, ['17']),
    ('17', 'TeammateAvg', None, None),
    ('17', 'ClassAvg', get_class_average_all_teammates, ['17']),
    ('17', 'ClassStDev', get_class_stdev_all_teammates, ['17']),
    ('18', 'Me', get_my_response, ['18']),
    ('18', 'TeammateAvg', None, None),
    ('18', 'ClassAvg', get_class_average_all_teammates, ['18']),
    ('18', 'ClassStDev', get_class_stdev_all_teammates, ['18']),
    ('19', 'Me', get_my_response, ['19']),
    ('19', 'TeammateAvg', None, None),
    ('19', 'ClassAvg', get_class_average_all_teammates, ['19']),
    ('19', 'ClassStDev', get_class_stdev_all_teammates, ['19']),
]
result = column_builder_pipe(full_cleaned, sample_params)
# Out:
# /tmp/ipykernel_13263/387846762.py:24: RuntimeWarning: Mean of empty slice
#   return np.nanmean(apply_df)
# /tmp/ipykernel_13263/387846762.py:24: RuntimeWarning: Mean of empty slice
#   return np.nanmean(apply_df)
# /tmp/ipykernel_13263/387846762.py:24: RuntimeWarning: Mean of empty slice
#   return np.nanmean(apply_df)
# /tmp/ipykernel_13263/387846762.py:24: RuntimeWarning: Mean of empty slice
#   return np.nanmean(apply_df)

# %%
cols_to_remove = ~full_cleaned.columns.str.contains(r'[0-9]', regex=True)
padded = list(cols_to_remove) + [np.True_] * (len(result.columns) - len(cols_to_remove))
result.loc[:, np.array(padded)]
# Out:
#                                Email  TeamNumber  TeammateNumber  \
# 0            allanzhong@berkeley.edu         1.0               1
# 1             eclopez19@berkeley.edu         1.0               2
# 2               jerrick@berkeley.edu         1.0               3
# 3              simrankk@berkeley.edu         1.0               4
# 4          miroygarrett@berkeley.edu        10.0               1
# ..                               ...         ...             ...
# 128  siddhant.vasudevan@berkeley.edu         8.0               4
# 129        allan.sram16@berkeley.edu         9.0               1
# 130            arnavp45@berkeley.edu         9.0               2
# 131           owenlachs@berkeley.edu         9.0               3
# 132          tyler.peng@berkeley.edu         9.0               4
#
#     RecipientFirstName             RecipientEmail  SharedGoalTeamAvg  \
# 0                Allan    allanzhong@berkeley.edu           2.333333
# 1          No Response                No Response           2.333333
# 2              Jerrick       jerrick@berkeley.edu           2.333333
# 3               Simran      simrankk@berkeley.edu           2.333333
# 4                 Miro  miroygarrett@berkeley.edu           2.500000
# ..                 ...                        ...                ...
# 128        No Response                No Response           3.000000
# 129        No Response                No Response           1.666667
# 130              Arnav      arnavp45@berkeley.edu           1.666667
# 131               Owen     owenlachs@berkeley.edu           1.666667
# 132              Tyler    tyler.peng@berkeley.edu           1.666667
#
#      SharedGoalClassAvg  SharedGoalClassStDev  IndvGoalTeamAvg  \
# 0              2.408696              0.853592         2.333333
# 1              2.408696              0.853592         2.333333
# 2              2.408696              0.853592         2.333333
# 3              2.408696              0.853592         2.333333
# 4              2.408696              0.853592         2.250000
# ..                  ...                   ...              ...
# 128            2.408696              0.853592         2.666667
# 129            2.408696              0.853592         1.666667
# 130            2.408696              0.853592         1.666667
# 131            2.408696              0.853592         1.666667
# 132            2.408696              0.853592         1.666667
#
#      SupportTeamAvg  ...  CommunicateMe  CommunicateTeammateAvg  ExpertiseMe  \
# 0          2.000000  ...            2.0                2.000000          2.0
# 1          2.000000  ...            NaN                2.000000          NaN
# 2          2.000000  ...            3.0                1.500000          3.0
# 3          2.000000  ...            1.0                2.500000          1.0
# 4          3.000000  ...            2.0                2.333333          2.0
# ..              ...  ...            ...                     ...          ...
# 128        2.666667  ...            NaN                3.000000          NaN
# 129        2.333333  ...            NaN                2.000000          NaN
# 130        2.333333  ...            3.0                2.000000          3.0
# 131        2.333333  ...            3.0                3.000000          3.0
# 132        2.333333  ...            3.0                2.000000          3.0
#
#      ExpertiseTeammateAvg  ExpertiseClassAvg  ExpertiseClassStDev  RespectMe  \
# 0                3.000000           2.490826             0.776612        2.0
# 1                1.333333           2.490826             0.776612        NaN
# 2                1.500000           2.490826             0.776612        3.0
# 3                2.500000           2.490826             0.776612        1.0
# 4                2.333333           2.490826             0.776612        1.0
# ..                    ...                ...                  ...        ...
# 128              3.000000           2.490826             0.776612        NaN
# 129              2.666667           2.490826             0.776612        NaN
# 130              3.000000           2.490826             0.776612        3.0
# 131              3.000000           2.490826             0.776612        3.0
# 132              3.000000           2.490826             0.776612        3.0
#
#      RespectTeammateAvg  RespectClassAvg  RespectClassStDev
# 0              1.000000         2.549774           0.729788
# 1              1.333333         2.549774           0.729788
# 2              1.000000         2.549774           0.729788
# 3              2.500000         2.549774           0.729788
# 4              2.666667         2.549774           0.729788
# ..                  ...              ...                ...
# 128            3.000000         2.549774           0.729788
# 129            3.000000         2.549774           0.729788
# 130            3.000000         2.549774           0.729788
# 131            3.000000         2.549774           0.729788
# 132            2.500000         2.549774           0.729788
#
# [133 rows x 50 columns]
